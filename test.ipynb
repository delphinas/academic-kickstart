# %%
import plotly
import plotly.io as pio
import plotly.graph_objects as go
from IPython.display import Image

# %%
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with the 'svg' Renderer"
)
img_b = fig.to_image(format="png")

# %%
Image(img_b)
